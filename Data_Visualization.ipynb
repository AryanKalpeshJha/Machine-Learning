# %% [markdown]
# Name: Aryan Jha
#
# Program: MBA TECH AI
#
# Cousre: Machine Learning
#
# Topic: To understand and implement Data Visualization techniques

# %%
import seaborn as sns

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/content/seeds.csv")

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             199 non-null    float64
#  1   Perimeter        199 non-null    float64
#  2   Compactness      199 non-null    float64
#  3   Kernel.Length    199 non-null    float64
#  4   Kernel.Width     199 non-null    float64
#  5   Asymmetry.Coeff  199 non-null    float64
#  6   Kernel.Groove    199 non-null    float64
#  7   Type             199 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 12.6 KB

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
plt.savefig('fig 1')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'g')
plt.subplot(2,2,2)
plt.plot(x,y,'r--')
plt.subplot(2,2,3)
plt.plot(x,y,'b*--')
plt.subplot(2,2,4)
plt.scatter(x,y,color = 'red')

# %%
x = [2,8,10]
y = [11,16,9]
plt.bar(x,y)
plt.show()

# %%
A = [3,4,5,7,9,8,12,13,7,8,19,90,12,15]
plt.boxplot(A)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc8f9fbf430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc8f9fbfaf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc8f9fbf0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc8f9fc91f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc8f9fc94f0>],
#  'means': []}

# %%
df=pd.read_csv("///content/seeds.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             199 non-null    float64
#  1   Perimeter        199 non-null    float64
#  2   Compactness      199 non-null    float64
#  3   Kernel.Length    199 non-null    float64
#  4   Kernel.Width     199 non-null    float64
#  5   Asymmetry.Coeff  199 non-null    float64
#  6   Kernel.Groove    199 non-null    float64
#  7   Type             199 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 12.6 KB

# %%
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.857100       5.267000      2.954500
# 50%     14.430000   14.370000     0.873400       5.541000      3.245000
# 75%     17.455000   15.805000     0.886800       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...

# %%
df['Type'].value_counts(ascending = True)
# Out:
# 3    65
# 1    66
# 2    68
# Name: Type, dtype: int64

# %%
df['Type'].value_counts().plot.bar()

# %%
sns.countplot('Type',data=df);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(df['Kernel.Length'],df['Kernel.Width'],color = 'red')

# %%
sns.scatterplot(x = 'Kernel.Length', y = 'Kernel.Width',data = df, color = 'red')

# %%
sns.scatterplot(x = 'Kernel.Length', y = 'Kernel.Width',data = df, hue = 'Type', palette = ('deep'))

# %%
sns.jointplot(x = 'Perimeter',y= 'Compactness',data = df)

# %%
sns.boxplot(x = 'Type',y= 'Compactness',data = df)

# %%
sns.pairplot(df, hue = 'Type', diag_kind= 'hist')
